# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/data/dataset.zip > /dev/null

# %%
# Import Libraries

import matplotlib.pylab as plt
import tensorflow_hub as hub
from tensorflow.keras import layers
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read image paths

imagePaths=[]
for root, dirnames, filenames in os.walk(r'dataset'):
    for filename in filenames:
        if (filename[-3:] == 'jpg'):
            imagePaths.append(os.path.join(root, filename))
            
print(len(imagePaths))
# Out:
# 25260

# %%
image=plt.imread(imagePaths[0])
image.shape
# Out:
# (128, 64, 3)

# %%
# AutoEncoder

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, Flatten, Dense, Reshape, BatchNormalization
from tensorflow.keras.optimizers import Adam

input_shape=(64, 64, 3)
encoding_dim = 32

# Encoder
encoder = Sequential([
    Conv2D(input_shape=input_shape, filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(32, (3, 3), activation='LeakyReLU', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(16, (3, 3), activation='LeakyReLU', padding='same'),
    Flatten(),
    BatchNormalization(),
    Dense(256, activation='LeakyReLU'),
    BatchNormalization(),
    Dense(128, activation='LeakyReLU'),
    Dense(encoding_dim, activation='LeakyReLU')
])

# Decoder
decoder = Sequential([
    Dense(128, activation='LeakyReLU', input_shape=(encoding_dim,)),
    BatchNormalization(),
    Dense(256, activation='LeakyReLU'),
    BatchNormalization(),
    Dense(16*16*3, activation='LeakyReLU'),
    Reshape((16, 16, 3)),
    UpSampling2D((2, 2)),
    Conv2D(32, (3, 3), activation='LeakyReLU', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(64, (3, 3), activation='LeakyReLU', padding='same'),
    Conv2D(3, (3, 3), activation='sigmoid', padding='same')
])

# Compile the model

autoencoder_dr = Model(inputs = encoder.inputs, outputs = decoder(encoder.outputs))
autoencoder_dr.compile(optimizer=Adam(learning_rate=0.005), loss = 'mean_squared_error')

# %%
autoencoder_dr.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6_input (InputLayer)  [(None, 64, 64, 3)]      0
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 64)        1792
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        18464
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 16)        4624
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  batch_normalization_4 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  dense_6 (Dense)             (None, 256)               1048832
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 32)                4128
#
#  sequential_3 (Sequential)   (None, 64, 64, 3)         257283
#
# =================================================================
# Total params: 1,385,427
# Trainable params: 1,375,955
# Non-trainable params: 9,472
# _________________________________________________________________

# %%
decoder.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               4224
#
#  batch_normalization_6 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_10 (Dense)            (None, 256)               33024
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_11 (Dense)            (None, 768)               197376
#
#  reshape_1 (Reshape)         (None, 16, 16, 3)         0
#
#  up_sampling2d_2 (UpSampling  (None, 32, 32, 3)        0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        896
#
#  up_sampling2d_3 (UpSampling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 64)        18496
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 3)         1731
#
# =================================================================
# Total params: 257,283
# Trainable params: 256,515
# Non-trainable params: 768
# _________________________________________________________________

# %%
#Early Sopping

from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

# %%
from sklearn.model_selection import train_test_split

# Test Train Split

imagePathsTrain, imagePathsTest = train_test_split(imagePaths, test_size=0.1, random_state=42)
print(len(imagePathsTrain), len(imagePathsTest))
# Out:
# 22734 2526

# %%
x_train = []
x_val = []
train = []

for i in range(len(imagePathsTrain)):
  if i%7000 == 0 and i!=0:
    # Train the autoencoder
    x_train, x_val = train_test_split(train, test_size=0.1, random_state=42)
    x_train = np.array(x_train)
    x_val = np.array(x_val)
    print(np.array(train).shape, x_train.shape, x_val.shape, i)
    autoencoder_dr.fit(x_train, x_train, epochs=100, batch_size=64, shuffle=True, validation_data=(x_val, x_val), callbacks=[es])
    train = []
    x_train = []
    x_val = []
  try:
    # Process the images
    image=plt.imread(imagePaths[i])
    image=cv2.resize(image, (64, 64))
    image = image/255
    train.append(image)
  except:
    pass
x_train, x_val = train_test_split(train, test_size=0.2, random_state=42)
x_train = np.array(x_train)
x_val = np.array(x_val)
print(np.array(train).shape, x_train.shape, x_val.shape)
autoencoder_dr.fit(x_train, x_train, epochs=100, batch_size=32, shuffle=True, validation_data=(x_val, x_val), callbacks=[es])
# Out:
# (7000, 64, 64, 3) (6300, 64, 64, 3) (700, 64, 64, 3) 7000
# Epoch 1/100
# 99/99 [==============================] - 23s 52ms/step - loss: 0.0238 - val_loss: 0.0351
# Epoch 2/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0188 - val_loss: 0.0280
# Epoch 3/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0175 - val_loss: 0.0223
# Epoch 4/100
# 99/99 [==============================] - 4s 37ms/step - loss: 0.0168 - val_loss: 0.0220
# Epoch 5/100
# 99/99 [==============================] - 4s 36ms/step - loss: 0.0163 - val_loss: 0.0190
# Epoch 6/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0160 - val_loss: 0.0196
# Epoch 7/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0157 - val_loss: 0.0168
# Epoch 8/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0155 - val_loss: 0.0164
# Epoch 9/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0153 - val_loss: 0.0156
# Epoch 10/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0151 - val_loss: 0.0171
# Epoch 11/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0150 - val_loss: 0.0191
# Epoch 12/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0150 - val_loss: 0.0164
# Epoch 13/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0149 - val_loss: 0.0165
# Epoch 14/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0148 - val_loss: 0.0180
# Epoch 15/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0147 - val_loss: 0.0176
# Epoch 16/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0146 - val_loss: 0.0148
# Epoch 17/100
# 99/99 [==============================] - 4s 41ms/step - loss: 0.0146 - val_loss: 0.0149
# Epoch 18/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0145 - val_loss: 0.0151
# Epoch 19/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0145 - val_loss: 0.0154
# Epoch 20/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0145 - val_loss: 0.0189
# Epoch 21/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0144 - val_loss: 0.0152
# Epoch 22/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0144 - val_loss: 0.0163
# Epoch 23/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0143 - val_loss: 0.0152
# Epoch 24/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0143 - val_loss: 0.0148
# Epoch 25/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0143 - val_loss: 0.0151
# Epoch 26/100
# 99/99 [==============================] - 4s 37ms/step - loss: 0.0142 - val_loss: 0.0149
# Epoch 27/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0142 - val_loss: 0.0147
# Epoch 28/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0141 - val_loss: 0.0152
# Epoch 29/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0142 - val_loss: 0.0148
# Epoch 30/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0141 - val_loss: 0.0193
# Epoch 31/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0139 - val_loss: 0.0149
# Epoch 32/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0138 - val_loss: 0.0175
# Epoch 33/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0138 - val_loss: 0.0145
# Epoch 34/100
# 99/99 [==============================] - 4s 36ms/step - loss: 0.0138 - val_loss: 0.0146
# Epoch 35/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0137 - val_loss: 0.0146
# Epoch 36/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0136 - val_loss: 0.0159
# Epoch 37/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0136 - val_loss: 0.0155
# Epoch 38/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0135 - val_loss: 0.0163
# Epoch 39/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0135 - val_loss: 0.0148
# Epoch 40/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0134 - val_loss: 0.0146
# Epoch 41/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0134 - val_loss: 0.0147
# Epoch 42/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0133 - val_loss: 0.0145
# Epoch 43/100
# 99/99 [==============================] - 4s 36ms/step - loss: 0.0133 - val_loss: 0.0165
# Epoch 44/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0133 - val_loss: 0.0143
# Epoch 45/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0134 - val_loss: 0.0145
# Epoch 46/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0133 - val_loss: 0.0188
# Epoch 47/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0134 - val_loss: 0.0146
# Epoch 48/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0132 - val_loss: 0.0157
# Epoch 49/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0132 - val_loss: 0.0146
# Epoch 50/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0132 - val_loss: 0.0146
# Epoch 51/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0131 - val_loss: 0.0146
# Epoch 52/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0131 - val_loss: 0.0146
# Epoch 53/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0131 - val_loss: 0.0145
# Epoch 54/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0131 - val_loss: 0.0151
# Epoch 55/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0130 - val_loss: 0.0144
# Epoch 56/100
# 99/99 [==============================] - 4s 35ms/step - loss: 0.0130 - val_loss: 0.0146
# Epoch 57/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0131 - val_loss: 0.0147
# Epoch 58/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0130 - val_loss: 0.0167
# Epoch 59/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0130 - val_loss: 0.0147
# Epoch 60/100
# 99/99 [==============================] - 4s 39ms/step - loss: 0.0131 - val_loss: 0.0145
# Epoch 61/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0129 - val_loss: 0.0152
# Epoch 62/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0129 - val_loss: 0.0145
# Epoch 63/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0129 - val_loss: 0.0148
# Epoch 64/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0129 - val_loss: 0.0149
# Epoch 64: early stopping
# (7000, 64, 64, 3) (6300, 64, 64, 3) (700, 64, 64, 3) 14000
# Epoch 1/100
# 99/99 [==============================] - 4s 36ms/step - loss: 0.0145 - val_loss: 0.0176
# Epoch 2/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0141 - val_loss: 0.0140
# Epoch 3/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0139 - val_loss: 0.0142
# Epoch 4/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0139 - val_loss: 0.0144
# Epoch 5/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0138 - val_loss: 0.0146
# Epoch 6/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0137 - val_loss: 0.0141
# Epoch 7/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0138 - val_loss: 0.0142
# Epoch 8/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0136 - val_loss: 0.0138
# Epoch 9/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0136 - val_loss: 0.0139
# Epoch 10/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0135 - val_loss: 0.0146
# Epoch 11/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0136 - val_loss: 0.0138
# Epoch 12/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0135 - val_loss: 0.0144
# Epoch 13/100
# 99/99 [==============================] - 4s 36ms/step - loss: 0.0135 - val_loss: 0.0140
# Epoch 14/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0134 - val_loss: 0.0138
# Epoch 15/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0134 - val_loss: 0.0138
# Epoch 16/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0133 - val_loss: 0.0138
# Epoch 17/100
# 99/99 [==============================] - 4s 38ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 18/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0133 - val_loss: 0.0142
# Epoch 19/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0133 - val_loss: 0.0140
# Epoch 20/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 21/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0132 - val_loss: 0.0140
# Epoch 22/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0132 - val_loss: 0.0144
# Epoch 23/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0131 - val_loss: 0.0148
# Epoch 24/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0132 - val_loss: 0.0151
# Epoch 25/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0131 - val_loss: 0.0142
# Epoch 26/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0131 - val_loss: 0.0142
# Epoch 27/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0131 - val_loss: 0.0146
# Epoch 28/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0131 - val_loss: 0.0143
# Epoch 29/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0130 - val_loss: 0.0165
# Epoch 30/100
# 99/99 [==============================] - 4s 36ms/step - loss: 0.0130 - val_loss: 0.0141
# Epoch 31/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0130 - val_loss: 0.0144
# Epoch 31: early stopping
# (6999, 64, 64, 3) (6299, 64, 64, 3) (700, 64, 64, 3) 21000
# Epoch 1/100
# 99/99 [==============================] - 4s 41ms/step - loss: 0.0142 - val_loss: 0.0172
# Epoch 2/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0139 - val_loss: 0.0138
# Epoch 3/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0138 - val_loss: 0.0135
# Epoch 4/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0138 - val_loss: 0.0137
# Epoch 5/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0137 - val_loss: 0.0141
# Epoch 6/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0136 - val_loss: 0.0136
# Epoch 7/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0135 - val_loss: 0.0136
# Epoch 8/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0136 - val_loss: 0.0134
# Epoch 9/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0134 - val_loss: 0.0135
# Epoch 10/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0134 - val_loss: 0.0135
# Epoch 11/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0134 - val_loss: 0.0135
# Epoch 12/100
# 99/99 [==============================] - 4s 36ms/step - loss: 0.0134 - val_loss: 0.0134
# Epoch 13/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0134 - val_loss: 0.0144
# Epoch 14/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0133 - val_loss: 0.0137
# Epoch 15/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0133 - val_loss: 0.0134
# Epoch 16/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0132 - val_loss: 0.0135
# Epoch 17/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0132 - val_loss: 0.0146
# Epoch 18/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0132 - val_loss: 0.0134
# Epoch 19/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0132 - val_loss: 0.0135
# Epoch 20/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0131 - val_loss: 0.0134
# Epoch 21/100
# 99/99 [==============================] - 4s 36ms/step - loss: 0.0131 - val_loss: 0.0139
# Epoch 22/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0131 - val_loss: 0.0136
# Epoch 23/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0131 - val_loss: 0.0135
# Epoch 24/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0130 - val_loss: 0.0138
# Epoch 25/100
# 99/99 [==============================] - 4s 37ms/step - loss: 0.0130 - val_loss: 0.0134
# Epoch 26/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0130 - val_loss: 0.0137
# Epoch 27/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0130 - val_loss: 0.0138
# Epoch 28/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0130 - val_loss: 0.0136
# Epoch 29/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0129 - val_loss: 0.0137
# Epoch 30/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0129 - val_loss: 0.0140
# Epoch 31/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 32/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0129 - val_loss: 0.0146
# Epoch 33/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0129 - val_loss: 0.0136
# Epoch 34/100
# 99/99 [==============================] - 3s 34ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 35/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0129 - val_loss: 0.0137
# Epoch 36/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0128 - val_loss: 0.0146
# Epoch 37/100
# 99/99 [==============================] - 3s 33ms/step - loss: 0.0128 - val_loss: 0.0136
# Epoch 38/100
# 99/99 [==============================] - 3s 35ms/step - loss: 0.0128 - val_loss: 0.0141
# Epoch 39/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0128 - val_loss: 0.0136
# Epoch 40/100
# 99/99 [==============================] - 3s 32ms/step - loss: 0.0127 - val_loss: 0.0144
# Epoch 40: early stopping
# (1734, 64, 64, 3) (1387, 64, 64, 3) (347, 64, 64, 3)
# Epoch 1/100
# 44/44 [==============================] - 2s 35ms/step - loss: 0.0151 - val_loss: 0.0203
# Epoch 2/100
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0147 - val_loss: 0.0163
# Epoch 3/100
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0147 - val_loss: 0.0175
# Epoch 4/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0143 - val_loss: 0.0160
# Epoch 5/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0141 - val_loss: 0.0157
# Epoch 6/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0140 - val_loss: 0.0147
# Epoch 7/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0138 - val_loss: 0.0149
# Epoch 8/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0138 - val_loss: 0.0145
# Epoch 9/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0137 - val_loss: 0.0144
# Epoch 10/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0136 - val_loss: 0.0146
# Epoch 11/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0135 - val_loss: 0.0156
# Epoch 12/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0134 - val_loss: 0.0153
# Epoch 13/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0135 - val_loss: 0.0147
# Epoch 14/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0133 - val_loss: 0.0147
# Epoch 15/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0134 - val_loss: 0.0151
# Epoch 16/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0131 - val_loss: 0.0153
# Epoch 17/100
# 44/44 [==============================] - 1s 24ms/step - loss: 0.0131 - val_loss: 0.0147
# Epoch 18/100
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0130 - val_loss: 0.0149
# Epoch 19/100
# 44/44 [==============================] - 1s 23ms/step - loss: 0.0131 - val_loss: 0.0146
# Epoch 20/100
# 44/44 [==============================] - 1s 20ms/step - loss: 0.0131 - val_loss: 0.0150
# Epoch 21/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0131 - val_loss: 0.0151
# Epoch 22/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0129 - val_loss: 0.0151
# Epoch 23/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0129 - val_loss: 0.0151
# Epoch 24/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0128 - val_loss: 0.0147
# Epoch 25/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0127 - val_loss: 0.0147
# Epoch 26/100
# 44/44 [==============================] - 1s 21ms/step - loss: 0.0128 - val_loss: 0.0161
# Epoch 27/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0127 - val_loss: 0.0149
# Epoch 28/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0127 - val_loss: 0.0150
# Epoch 29/100
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0127 - val_loss: 0.0152
# Epoch 29: early stopping

# %%
autoencoder_dr.save("autoencoder_v4.h5")

# %%
encoder.save("encoder_v4.h5")
decoder.save("decoder_v4.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Test reconstruction

x_test=[]
for i in range(len(imagePathsTest)):
  image=plt.imread(imagePaths[i])
  image=cv2.resize(image, (64, 64))
  image = image/255
  x_test.append(image)
x_test=np.array(x_test)

reconstructed_img = autoencoder_dr(x_test[0:5])

f, axs = plt.subplots(2, 5, figsize=(15, 8))
for j in range(5):
    axs[0, j].imshow(x_test[j], cmap='binary')
    axs[1, j].imshow(reconstructed_img[j].numpy().squeeze(), cmap='binary')
    axs[0, j].axis('off')
    axs[1, j].axis('off')

# %%
# Write features to files

fp = open("autoencoder_features_v4.txt", "w")
for i in imagePaths:
  try:
    image=plt.imread(i)
    image = image/255
    image=cv2.resize(image, (64, 64))
    print(i+","+",".join(map(str, encoder(np.array([image])).numpy()[0].tolist())))
    fp.write(i+","+",".join(map(str, encoder(np.array([image])).numpy()[0].tolist()))+"\n")
  except:
    pass
fp.close()
